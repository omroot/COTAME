# %% [markdown]
# | Ticker | Real Name              | Description                                                                 | Exchange / Calendar       |
# |--------|------------------------|-----------------------------------------------------------------------------|---------------------------|
# | **CL** | WTI Crude Oil          | Light Sweet Crude Oil futures; U.S. benchmark.                              | **NYMEX (CME Group)**     |
# | **CO** | Brent Crude Oil        | Brent Crude futures; global oil benchmark.                                 | **ICE Futures Europe**    |
# | **XB** | RBOB Gasoline          | Reformulated gasoline futures; U.S. retail fuel benchmark.                 | **NYMEX (CME Group)**     |
# | **HO** | Heating Oil / ULSD     | Ultra-Low Sulfur Diesel (ULSD) futures (formerly Heating Oil).             | **NYMEX (CME Group)**     |
# | **QS** | Low Sulphur Gasoil     | European diesel benchmark futures.                                         | **ICE Futures Europe**    |
#
# ### Summary of Calendars
#
# - **CL, XB, HO** → Follow **CME Group business calendar** (NYMEX)
# - **CO, QS** → Follow **ICE business calendar** (ICE Futures Europe)
