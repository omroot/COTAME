# %% [markdown]
# # RBOB COT Commercial Forecasting EDA

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd

# %%
import scipy.stats as stats

# %%
import sys
sys.path.append('../../../')

# %%
import matplotlib.pyplot as plt

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
from src.utils.dates import get_nyse_business_dates
from src.utils.io.read import PreprocessedDataReader

# %%
from src.preprocessing.base import FutureTicker

# %%
from src.settings import Settings

# %%
from research.metrics import get_features_responses_correlation
from research.plots import plot_bin_summary_of_xy

# %%
pdr = PreprocessedDataReader(Settings.historical.paths.PREPROCESSED_DATA_PATH)

# %%
dataset = pdr.read_dataset(ticker=FutureTicker.RBOB)

# %%
dataset.shape
# Out:
# (809, 81)

# %%
dataset.tail(3)
# Out:
#       tradeDate Name  Commercial_NetPosition  CommercialLongPosition  \
# 806  2025-06-17   XB                -57590.0                137454.0
# 807  2025-06-24   XB                -60881.0                128882.0
# 808  2025-07-01   XB                -59728.0                120966.0
#
#      CommercialShortPosition  ManagedMoney_NetPosition  \
# 806                 195044.0                   30752.0
# 807                 189763.0                   36136.0
# 808                 180694.0                   30518.0
#
#      ManagedMoney_LongPosition  ManagedMoney_ShortPosition  \
# 806                    75785.0                     45033.0
# 807                    80365.0                     44229.0
# 808                    78539.0                     48021.0
#
#      Commercial_NetPosition_change  \
# 806                          285.0
# 807                        -3291.0
# 808                         1153.0
#
#      prior_report_Commercial_NetPosition_change  ...  \
# 806                                      3341.0  ...
# 807                                       285.0  ...
# 808                                     -3291.0  ...
#
#      prior_cumulative_5D_F2_Volume_change  \
# 806                              191829.0
# 807                               39197.0
# 808                             -192059.0
#
#      next_prior_cumulative_5D_F2_Volume_change  \
# 806                                    39197.0
# 807                                  -192059.0
# 808                                        NaN
#
#      prior_cumulative_5D_F1MinusF2_Volume_change  \
# 806                                    -201086.0
# 807                                    -147137.0
# 808                                     100858.0
#
#      next_prior_cumulative_5D_F1MinusF2_Volume_change  F1_RolledPrice_change  \
# 806                                         -147137.0                  18.39
# 807                                          100858.0                 -18.62
# 808                                               NaN                   3.50
#
#      next_F1_RolledPrice_change  F2_RolledPrice_change  \
# 806                      -18.62                  18.57
# 807                        3.50                 -18.76
# 808                         NaN                   2.69
#
#      next_F2_RolledPrice_change  F3_RolledPrice_change  \
# 806                      -18.76                  18.30
# 807                        2.69                 -18.46
# 808                         NaN                   2.10
#
#      next_F3_RolledPrice_change
# 806                      -18.46
# 807                        2.10
# 808                         NaN
#
# [3 rows x 81 columns]

# %%
dataset['tradeDate'].min(),dataset['tradeDate'].max()
# Out:
# ('2010-01-05', '2025-07-01')

# %%
dataset['tradeDate'] = pd.to_datetime(dataset['tradeDate']).dt.date

# %%
plt.rcParams["figure.figsize"] = (14,5)
plt.plot_date(dataset['tradeDate'],dataset['forward_Commercial_NetPosition_to_openinterest_change'], '-')
plt.plot_date(dataset['tradeDate'],dataset['forward_CommercialLongPosition_to_openinterest_change'], '-')
plt.plot_date(dataset['tradeDate'],dataset['forward_CommercialShortPosition_to_openinterest_change'], '-')
plt.legend(['Net', 'Long', 'Short'])
plt.title('WTI - Commercial Position/OI Change')
plt.grid()

# %%
forward_response_names = ['forward_Commercial_NetPosition_to_openinterest_change',
                            'forward_CommercialLongPosition_to_openinterest_change',
                            'forward_CommercialShortPosition_to_openinterest_change']

prior_response_names = ['prior_report_Commercial_NetPosition_to_openinterest_change',
                            'prior_report_CommercialLongPosition_to_openinterest_change',
                            'prior_report_CommercialShortPosition_to_openinterest_change']

# %%
get_features_responses_correlation(dataset = dataset,
                                   features = prior_response_names,
                                   responses=forward_response_names).sort_values(by = forward_response_names[0])
# Out:
#                                              Feature  \
# 0  prior_report_Commercial_NetPosition_to_openint...
# 1  prior_report_CommercialLongPosition_to_openint...
# 2  prior_report_CommercialShortPosition_to_openin...
#
#    forward_Commercial_NetPosition_to_openinterest_change  \
# 0                                          -0.191914
# 1                                          -0.154666
# 2                                           0.047162
#
#    forward_CommercialLongPosition_to_openinterest_change  \
# 0                                          -0.193622
# 1                                          -0.171486
# 2                                           0.019134
#
#    forward_CommercialShortPosition_to_openinterest_change
# 0                                           0.010364
# 1                                          -0.012910
# 2                                          -0.058606
