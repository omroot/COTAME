# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd

# %%
import sys
sys.path.append('../../../')

# %%
import matplotlib.pyplot as plt

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
from src.utils.dates import get_nyse_business_dates

# %%
from research.metrics import get_features_responses_correlation
from research.plots import plot_bin_summary_of_xy

# %%
from src.settings import Settings

# %%
from src.utils.io.read import PreprocessedDataReader

# %%
from src.preprocessing.base import FutureTicker

# %%
pdr = PreprocessedDataReader(Settings.historical.paths.PREPROCESSED_DATA_PATH)

# %%
dataset = pdr.read_dataset(ticker=FutureTicker.WTI)

# %%
dataset.shape
# Out:
# (813, 83)

# %%
dataset.tail(2)
# Out:
#       tradeDate feature_date  Commercial_NetPosition  CommercialLongPosition  \
# 811  2025-07-22   2025-07-21                355309.0               1179861.0
# 812  2025-07-29   2025-07-28                362436.0               1172427.0
#
#      CommercialShortPosition  ManagedMoney_NetPosition  \
# 811                 824552.0                  208836.0
# 812                 809991.0                  207342.0
#
#      ManagedMoney_LongPosition  ManagedMoney_ShortPosition release_date  \
# 811                   406472.0                    197636.0   2025-07-25
# 812                   411275.0                    203933.0   2025-08-01
#
#      Commercial_NetPosition_change  ...  \
# 811                       -13379.0  ...
# 812                         7127.0  ...
#
#      prior_cumulative_5D_F1MinusF2_Volume_change  \
# 811                                    -706796.0
# 812                                     704600.0
#
#      next_prior_cumulative_5D_F1MinusF2_Volume_change  F1_RolledPrice_change  \
# 811                                          704600.0                   0.26
# 812                                               NaN                   0.76
#
#      next_F1_RolledPrice_change  F2_RolledPrice_change  \
# 811                        0.76                   0.23
# 812                         NaN                   0.89
#
#      next_F2_RolledPrice_change  F3_RolledPrice_change  \
# 811                        0.89                   0.30
# 812                         NaN                   0.87
#
#      next_F3_RolledPrice_change  SyntheticF1MinusF2_RolledPrice_change  \
# 811                        0.87                              -7.265886
# 812                         NaN                              -0.565494
#
#      next_SyntheticF1MinusF2_RolledPrice_change
# 811                                   -0.565494
# 812                                         NaN
#
# [2 rows x 83 columns]

# %%
dataset.columns.tolist()
# Out:
# ['tradeDate',
#  'feature_date',
#  'Commercial_NetPosition',
#  'CommercialLongPosition',
#  'CommercialShortPosition',
#  'ManagedMoney_NetPosition',
#  'ManagedMoney_LongPosition',
#  'ManagedMoney_ShortPosition',
#  'release_date',
#  'Commercial_NetPosition_change',
#  'prior_report_Commercial_NetPosition_change',
#  'forward_report_Commercial_NetPosition_change',
#  'CommercialLongPosition_change',
#  'prior_report_CommercialLongPosition_change',
#  'forward_report_CommercialLongPosition_change',
#  'CommercialShortPosition_change',
#  'prior_report_CommercialShortPosition_change',
#  'forward_report_CommercialShortPosition_change',
#  'ManagedMoney_NetPosition_change',
#  'prior_report_ManagedMoney_NetPosition_change',
#  'forward_report_ManagedMoney_NetPosition_change',
#  'ManagedMoney_LongPosition_change',
#  'prior_report_ManagedMoney_LongPosition_change',
#  'forward_report_ManagedMoney_LongPosition_change',
#  'ManagedMoney_ShortPosition_change',
#  'prior_report_ManagedMoney_ShortPosition_change',
#  'forward_report_ManagedMoney_ShortPosition_change',
#  'F1_RolledPrice',
#  'F2_RolledPrice',
#  'F3_RolledPrice',
#  'F1_RolledPrice_rolling_20D_volatility',
#  'F2_RolledPrice_rolling_20D_volatility',
#  'F3_RolledPrice_rolling_20D_volatility',
#  'SyntheticF1MinusF2_RolledPrice',
#  'prior_cumulative_5D_F1_Volume',
#  'prior_cumulative_5D_F2_Volume',
#  'prior_cumulative_5D_F1MinusF2_Volume',
#  'F1_OI',
#  'F2_OI',
#  'F3_OI',
#  'AGG_OI',
#  'prior_5D_F1_OI_change',
#  'prior_5D_F2_OI_change',
#  'prior_5D_AGG_OI_change',
#  'prior_5D_F1MinusF2_openinterest_change',
#  'Commercial_NetPosition_to_openinterest',
#  'CommercialLongPosition_to_openinterest',
#  'CommercialShortPosition_to_openinterest',
#  'ManagedMoney_NetPosition_to_openinterest',
#  'ManagedMoney_LongPosition_to_openinterest',
#  'ManagedMoney_ShortPosition_to_openinterest',
#  'Commercial_NetPosition_to_openinterest_change',
#  'prior_report_Commercial_NetPosition_to_openinterest_change',
#  'forward_Commercial_NetPosition_to_openinterest_change',
#  'CommercialLongPosition_to_openinterest_change',
#  'prior_report_CommercialLongPosition_to_openinterest_change',
#  'forward_CommercialLongPosition_to_openinterest_change',
#  'CommercialShortPosition_to_openinterest_change',
#  'prior_report_CommercialShortPosition_to_openinterest_change',
#  'forward_CommercialShortPosition_to_openinterest_change',
#  'ManagedMoney_NetPosition_to_openinterest_change',
#  'prior_report_ManagedMoney_NetPosition_to_openinterest_change',
#  'forward_ManagedMoney_NetPosition_to_openinterest_change',
#  'ManagedMoney_LongPosition_to_openinterest_change',
#  'prior_report_ManagedMoney_LongPosition_to_openinterest_change',
#  'forward_ManagedMoney_LongPosition_to_openinterest_change',
#  'ManagedMoney_ShortPosition_to_openinterest_change',
#  'prior_report_ManagedMoney_ShortPosition_to_openinterest_change',
#  'forward_ManagedMoney_ShortPosition_to_openinterest_change',
#  'prior_cumulative_5D_F1_Volume_change',
#  'next_prior_cumulative_5D_F1_Volume_change',
#  'prior_cumulative_5D_F2_Volume_change',
#  'next_prior_cumulative_5D_F2_Volume_change',
#  'prior_cumulative_5D_F1MinusF2_Volume_change',
#  'next_prior_cumulative_5D_F1MinusF2_Volume_change',
#  'F1_RolledPrice_change',
#  'next_F1_RolledPrice_change',
#  'F2_RolledPrice_change',
#  'next_F2_RolledPrice_change',
#  'F3_RolledPrice_change',
#  'next_F3_RolledPrice_change',
#  'SyntheticF1MinusF2_RolledPrice_change',
#  'next_SyntheticF1MinusF2_RolledPrice_change']

# %%
dataset['Commercial_NetPosition'].describe()
# Out:
# count       813.000000
# mean     -11247.533825
# std      156021.927084
# min     -315658.000000
# 25%     -146916.000000
# 50%       13553.000000
# 75%       95631.000000
# max      368688.000000
# Name: Commercial_NetPosition, dtype: float64

# %%
dataset['ManagedMoney_NetPosition'].describe()
# Out:
# count       813.000000
# mean     405093.035670
# std      162420.952528
# min      100633.000000
# 25%      273760.000000
# 50%      366026.000000
# 75%      518079.000000
# max      848584.000000
# Name: ManagedMoney_NetPosition, dtype: float64

# %%
np.sum(dataset['ManagedMoney_LongPosition'] <= dataset['ManagedMoney_ShortPosition'])
# Out:
# np.int64(0)

# %%
dataset['tradeDate'] = pd.to_datetime(dataset['tradeDate']).dt.date

# %%
dataset.sort_values(by = 'tradeDate', ascending = True, inplace=True)

# %%
# for name in [ 'prior_cumulative_5D_F1_Volume',
#                  'prior_cumulative_5D_F2_Volume',
#                  'prior_cumulative_5D_F1MinusF2_Volume' ,
#             'F1_RolledPrice',
#  'F2_RolledPrice',
#  'F3_RolledPrice']:
#     dataset[f'{name}_change'] = dataset[name] - dataset[name].shift(1)
#     dataset[f'next_{name}_change'] =  dataset[name].shift(-1) - dataset[name]

# %%
display(dataset.columns.tolist())
# Out:
# ['tradeDate',
#  'feature_date',
#  'Commercial_NetPosition',
#  'CommercialLongPosition',
#  'CommercialShortPosition',
#  'ManagedMoney_NetPosition',
#  'ManagedMoney_LongPosition',
#  'ManagedMoney_ShortPosition',
#  'release_date',
#  'Commercial_NetPosition_change',
#  'prior_report_Commercial_NetPosition_change',
#  'forward_report_Commercial_NetPosition_change',
#  'CommercialLongPosition_change',
#  'prior_report_CommercialLongPosition_change',
#  'forward_report_CommercialLongPosition_change',
#  'CommercialShortPosition_change',
#  'prior_report_CommercialShortPosition_change',
#  'forward_report_CommercialShortPosition_change',
#  'ManagedMoney_NetPosition_change',
#  'prior_report_ManagedMoney_NetPosition_change',
#  'forward_report_ManagedMoney_NetPosition_change',
#  'ManagedMoney_LongPosition_change',
#  'prior_report_ManagedMoney_LongPosition_change',
#  'forward_report_ManagedMoney_LongPosition_change',
#  'ManagedMoney_ShortPosition_change',
#  'prior_report_ManagedMoney_ShortPosition_change',
#  'forward_report_ManagedMoney_ShortPosition_change',
#  'F1_RolledPrice',
#  'F2_RolledPrice',
#  'F3_RolledPrice',
#  'F1_RolledPrice_rolling_20D_volatility',
#  'F2_RolledPrice_rolling_20D_volatility',
#  'F3_RolledPrice_rolling_20D_volatility',
#  'SyntheticF1MinusF2_RolledPrice',
#  'prior_cumulative_5D_F1_Volume',
#  'prior_cumulative_5D_F2_Volume',
#  'prior_cumulative_5D_F1MinusF2_Volume',
#  'F1_OI',
#  'F2_OI',
#  'F3_OI',
#  'AGG_OI',
#  'prior_5D_F1_OI_change',
#  'prior_5D_F2_OI_change',
#  'prior_5D_AGG_OI_change',
#  'prior_5D_F1MinusF2_openinterest_change',
#  'Commercial_NetPosition_to_openinterest',
#  'CommercialLongPosition_to_openinterest',
#  'CommercialShortPosition_to_openinterest',
#  'ManagedMoney_NetPosition_to_openinterest',
#  'ManagedMoney_LongPosition_to_openinterest',
#  'ManagedMoney_ShortPosition_to_openinterest',
#  'Commercial_NetPosition_to_openinterest_change',
#  'prior_report_Commercial_NetPosition_to_openinterest_change',
#  'forward_Commercial_NetPosition_to_openinterest_change',
#  'CommercialLongPosition_to_openinterest_change',
#  'prior_report_CommercialLongPosition_to_openinterest_change',
#  'forward_CommercialLongPosition_to_openinterest_change',
#  'CommercialShortPosition_to_openinterest_change',
#  'prior_report_CommercialShortPosition_to_openinterest_change',
#  'forward_CommercialShortPosition_to_openinterest_change',
#  'ManagedMoney_NetPosition_to_openinterest_change',
#  'prior_report_ManagedMoney_NetPosition_to_openinterest_change',
#  'forward_ManagedMoney_NetPosition_to_openinterest_change',
#  'ManagedMoney_LongPosition_to_openinterest_change',
#  'prior_report_ManagedMoney_LongPosition_to_openinterest_change',
#  'forward_ManagedMoney_LongPosition_to_openinterest_change',
#  'ManagedMoney_ShortPosition_to_openinterest_change',
#  'prior_report_ManagedMoney_ShortPosition_to_openinterest_change',
#  'forward_ManagedMoney_ShortPosition_to_openinterest_change',
#  'prior_cumulative_5D_F1_Volume_change',
#  'next_prior_cumulative_5D_F1_Volume_change',
#  'prior_cumulative_5D_F2_Volume_change',
#  'next_prior_cumulative_5D_F2_Volume_change',
#  'prior_cumulative_5D_F1MinusF2_Volume_change',
#  'next_prior_cumulative_5D_F1MinusF2_Volume_change',
#  'F1_RolledPrice_change',
#  'next_F1_RolledPrice_change',
#  'F2_RolledPrice_change',
#  'next_F2_RolledPrice_change',
#  'F3_RolledPrice_change',
#  'next_F3_RolledPrice_change',
#  'SyntheticF1MinusF2_RolledPrice_change',
#  'next_SyntheticF1MinusF2_RolledPrice_change']

# %%
unscaled_response_names= ['ManagedMoney_NetPosition_change',
                          'ManagedMoney_LongPosition_change',
                          'ManagedMoney_ShortPosition_change']
scaled_response_names = ['ManagedMoney_NetPosition_to_openinterest_change',
                         'ManagedMoney_LongPosition_to_openinterest_change',
                         'ManagedMoney_ShortPosition_to_openinterest_change']
feature_names =  ['prior_report_ManagedMoney_NetPosition_change',
                  'prior_report_ManagedMoney_LongPosition_change',
                  'prior_report_ManagedMoney_ShortPosition_change',
                  'prior_report_ManagedMoney_NetPosition_to_openinterest_change',
                  'prior_report_ManagedMoney_LongPosition_to_openinterest_change',
                  'prior_report_ManagedMoney_ShortPosition_to_openinterest_change',
                #   'prior_report_SyntheticF1MinusF2_RolledPrice_change',
                  'prior_cumulative_5D_F1_Volume_change',
                  'prior_cumulative_5D_F2_Volume_change',
                  'prior_cumulative_5D_F1MinusF2_Volume_change',
                  'prior_5D_F1_OI_change',
                  'prior_5D_F2_OI_change',
                  'prior_5D_AGG_OI_change',
                  'prior_5D_F1MinusF2_openinterest_change',
                  'F1_RolledPrice_rolling_20D_volatility',
                  'F2_RolledPrice_rolling_20D_volatility',
                  'F3_RolledPrice_rolling_20D_volatility',
                  'F1_RolledPrice_change',
                  'F2_RolledPrice_change',
                  'F3_RolledPrice_change'
                 
                 ]

# %%
# ?get_features_responses_correlation
# Out:
# Signature:
# get_features_responses_correlation(
#     dataset: pandas.core.frame.DataFrame,
#     features: list[str],
#     responses: list[str],
#     method: str = 'spearman',
# ) -> pandas.core.frame.DataFrame
# Docstring: " Computes the correlation between a list of features and a list of responses
# File:      ~/Documents/Projects/omroot_repos/COTAME/research/metrics.py
# Type:      function

# %%
get_features_responses_correlation(dataset = dataset,
                                   features = feature_names,
                                   responses=unscaled_response_names).sort_values(by = unscaled_response_names[0])
# Out:
#                                               Feature  \
# 2      prior_report_ManagedMoney_ShortPosition_change
# 5   prior_report_ManagedMoney_ShortPosition_to_ope...
# 8         prior_cumulative_5D_F1MinusF2_Volume_change
# 6                prior_cumulative_5D_F1_Volume_change
# 13              F1_RolledPrice_rolling_20D_volatility
# 9                               prior_5D_F1_OI_change
# 12             prior_5D_F1MinusF2_openinterest_change
# 14              F2_RolledPrice_rolling_20D_volatility
# 15              F3_RolledPrice_rolling_20D_volatility
# 10                              prior_5D_F2_OI_change
# 7                prior_cumulative_5D_F2_Volume_change
# 11                             prior_5D_AGG_OI_change
# 4   prior_report_ManagedMoney_LongPosition_to_open...
# 1       prior_report_ManagedMoney_LongPosition_change
# 3   prior_report_ManagedMoney_NetPosition_to_openi...
# 0        prior_report_ManagedMoney_NetPosition_change
# 18                              F3_RolledPrice_change
# 17                              F2_RolledPrice_change
# 16                              F1_RolledPrice_change
#
#     ManagedMoney_NetPosition_change  ManagedMoney_LongPosition_change  \
# 2                         -0.106091                         -0.070016
# 5                         -0.103978                         -0.068677
# 8                         -0.082234                          0.034141
# 6                         -0.071238                          0.022026
# 13                        -0.069138                         -0.095278
# 9                         -0.068736                          0.044456
# 12                        -0.068064                          0.016460
# 14                        -0.065840                         -0.090334
# 15                        -0.064615                         -0.088189
# 10                         0.055703                          0.024487
# 7                          0.062828                         -0.052969
# 11                         0.068291                          0.244676
# 4                          0.097794                          0.064950
# 1                          0.117566                          0.069126
# 3                          0.150193                          0.072131
# 0                          0.166882                          0.079208
# 18                         0.502938                          0.345395
# 17                         0.510895                          0.348309
# 16                         0.512788                          0.345642
#
#     ManagedMoney_ShortPosition_change
# 2                            0.052160
# 5                            0.054369
# 8                            0.151479
# 6                            0.119643
# 13                           0.004455
# 9                            0.133175
# 12                           0.103608
# 14                           0.004893
# 15                           0.004949
# 10                          -0.049638
# 7                           -0.137520
# 11                           0.161829
# 4                           -0.074000
# 1                           -0.100684
# 3                           -0.125698
# 0                           -0.141375
# 18                          -0.311557
# 17                          -0.320545
# 16                          -0.328164

# %%
get_features_responses_correlation(dataset = dataset,
                                   features = feature_names,
                                   responses=scaled_response_names).sort_values(by = scaled_response_names[0])
# Out:
#                                               Feature  \
# 11                             prior_5D_AGG_OI_change
# 8         prior_cumulative_5D_F1MinusF2_Volume_change
# 6                prior_cumulative_5D_F1_Volume_change
# 9                               prior_5D_F1_OI_change
# 12             prior_5D_F1MinusF2_openinterest_change
# 5   prior_report_ManagedMoney_ShortPosition_to_ope...
# 2      prior_report_ManagedMoney_ShortPosition_change
# 13              F1_RolledPrice_rolling_20D_volatility
# 14              F2_RolledPrice_rolling_20D_volatility
# 15              F3_RolledPrice_rolling_20D_volatility
# 4   prior_report_ManagedMoney_LongPosition_to_open...
# 1       prior_report_ManagedMoney_LongPosition_change
# 10                              prior_5D_F2_OI_change
# 3   prior_report_ManagedMoney_NetPosition_to_openi...
# 0        prior_report_ManagedMoney_NetPosition_change
# 7                prior_cumulative_5D_F2_Volume_change
# 18                              F3_RolledPrice_change
# 17                              F2_RolledPrice_change
# 16                              F1_RolledPrice_change
#
#     ManagedMoney_NetPosition_to_openinterest_change  \
# 11                                        -0.336504
# 8                                         -0.284263
# 6                                         -0.265958
# 9                                         -0.162222
# 12                                        -0.126747
# 5                                         -0.119127
# 2                                         -0.115443
# 13                                        -0.016690
# 14                                        -0.013860
# 15                                        -0.012269
# 4                                          0.030312
# 1                                          0.042859
# 10                                         0.045855
# 3                                          0.101842
# 0                                          0.112279
# 7                                          0.209189
# 18                                         0.433236
# 17                                         0.443894
# 16                                         0.448722
#
#     ManagedMoney_LongPosition_to_openinterest_change  \
# 11                                         -0.480808
# 8                                          -0.330997
# 6                                          -0.324902
# 9                                          -0.141345
# 12                                         -0.102056
# 5                                          -0.106253
# 2                                          -0.097033
# 13                                         -0.007826
# 14                                         -0.002804
# 15                                          0.000739
# 4                                          -0.037584
# 1                                          -0.047830
# 10                                          0.008624
# 3                                           0.011596
# 0                                           0.007646
# 7                                           0.221896
# 18                                          0.233255
# 17                                          0.241143
# 16                                          0.243852
#
#     ManagedMoney_ShortPosition_to_openinterest_change
# 11                                          -0.119325
# 8                                            0.002587
# 6                                           -0.028096
# 9                                            0.074955
# 12                                           0.073661
# 5                                            0.020919
# 2                                            0.022021
# 13                                           0.041355
# 14                                           0.041774
# 15                                           0.042146
# 4                                           -0.115689
# 1                                           -0.148972
# 10                                          -0.075166
# 3                                           -0.144360
# 0                                           -0.161584
# 7                                           -0.041701
# 18                                          -0.331501
# 17                                          -0.338162
# 16                                          -0.343871

# %%
for  f  in feature_names:
    plt.rcParams["figure.figsize"] = (12,4)
    plt.subplot(1, 3, 1)
    _=plot_bin_summary_of_xy(
                    x = dataset[f],
                    y = dataset['ManagedMoney_NetPosition_change'],
                    k= 10 ,
        xlabel = f, 
        ylabel = 'ManagedMoney_NetPosition_change'
      )
    plt.grid()
    plt.subplot(1, 3, 2)
    _=plot_bin_summary_of_xy(
                        x = dataset[f],
                        y = dataset['ManagedMoney_LongPosition_change'],
                        k= 10 ,
            xlabel = f, 
            ylabel = 'ManagedMoney_LongPosition_change'
          )
    plt.grid()
    plt.subplot(1, 3, 3)
    _=plot_bin_summary_of_xy(
                        x = dataset[f],
                        y = dataset['ManagedMoney_ShortPosition_change'],
                        k= 10 ,
            xlabel = f, 
            ylabel = 'ManagedMoney_ShortPosition_change'
          )
    plt.tight_layout()
    plt.grid()
    plt.show()
    plt.close()

# %%
for  f  in feature_names:
    plt.rcParams["figure.figsize"] = (12,4)
    plt.subplot(1, 3, 1)
    _=plot_bin_summary_of_xy(
                    x = dataset[f],
                    y = dataset['ManagedMoney_NetPosition_to_openinterest_change'],
                    k= 10 ,
        xlabel = f, 
        ylabel = 'ManagedMoney_NetPosition_to_openinterest_change'
      )
    plt.grid()    
    plt.subplot(1, 3, 2)
    _=plot_bin_summary_of_xy(
                    x = dataset[f],
                    y = dataset['ManagedMoney_LongPosition_to_openinterest_change'],
                    k= 10 ,
        xlabel = f, 
        ylabel = 'ManagedMoney_LongPosition_to_openinterest_change'
      )
    plt.grid()    
    plt.subplot(1, 3, 3)
    _=plot_bin_summary_of_xy(
                    x = dataset[f],
                    y = dataset['ManagedMoney_ShortPosition_to_openinterest_change'],
                    k= 10 ,
        xlabel = f, 
        ylabel = 'ManagedMoney_ShortPosition_to_openinterest_change'
      )
    plt.tight_layout()
    
    plt.grid()
    plt.show()
    plt.close()

# %%
from research.model_selection.CombinatorialPurgedCV import CombinatorialPurgedCV
from research.model_selection.CombinatorialPurgedCV import cpcv_predict

# %%
from sklearn.linear_model import LinearRegression, ElasticNetCV
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor

# %%
# ?CombinatorialPurgedCV
# Out:
# Init signature: CombinatorialPurgedCV(n_partitions: int, k: int, purge_amount: int)
# Docstring:
# Combinatorial Purged Cross-Validatpr with Purging
#
# This class identifies training and testing indicies that split the data into train/test sets. It also implements purging to avoid lookahead bias.
# Init docstring:
# Args:
# :param n_partitions: the total number of partitions
# :param k: the number of partitions to include in the test set
# :param purge_amount: the number of indices to be purged between train/test sets
# File:           ~/Documents/Projects/omroot_repos/COTAME/research/model_selection/CombinatorialPurgedCV.py
# Type:           type
# Subclasses:

# %%
cv = CombinatorialPurgedCV(n_partitions=5,
                           k=1,
                           purge_amount=10)

# %%
Xy = dataset[['tradeDate']+feature_names+unscaled_response_names+scaled_response_names].dropna()
Xy.reset_index(drop=True, inplace= True)

# %%
relevance_model = HistGradientBoostingRegressor(max_iter=10)
redundancy_model = HistGradientBoostingRegressor(max_iter=10)

# %%
from  research.feature_selection.master_selector import MasterSelector

# %%
selected_features_by_response = {}
feature_selection_details = {}
for response in ['ManagedMoney_NetPosition_change',
                'ManagedMoney_LongPosition_change',
                'ManagedMoney_ShortPosition_change',
                'ManagedMoney_NetPosition_to_openinterest_change',
                'ManagedMoney_LongPosition_to_openinterest_change',
                'ManagedMoney_ShortPosition_to_openinterest_change']:
    print(response)
    master_selector_builder = MasterSelector( cv = cv,
                                     relevance_model = relevance_model,
                                     redundancy_model = redundancy_model,
                                     feature_names  = feature_names,
                                     response_name  = response,
                                     feature_similarity_method  = 'pearson',
                                     is_classification  = False,
                                     verbose  = False
                                     ) 
    master_selector_builder.fit(dataset=Xy)
    selected_feature_names = master_selector_builder.selected_feature_names
    print(selected_feature_names)
    selected_features_by_response[response] = selected_feature_names

    # Cluster MDA scores
    cluster_mda_scores = {}
    for cluster_name in master_selector_builder.feature_clusters:
        if cluster_name in master_selector_builder.clustered_mda.index:
            cluster_mda_scores[cluster_name] = {
                "mean": float(master_selector_builder.clustered_mda.loc[cluster_name, "Clustered MDA"]),
                "std": float(master_selector_builder.clustered_mda.loc[cluster_name, "CMDAStd"]),
            }

    # Per-feature SFI scores (within selected clusters)
    feature_sfi_scores = {}
    for cluster_name, sfi_df in master_selector_builder.feature_sfi.items():
        feature_sfi_scores[cluster_name] = {
            feat: {"mean": float(row["mean"]), "std": float(row["std"])}
            for feat, row in sfi_df.iterrows()
        }

    feature_selection_details[response] = {
        "number_of_feature_clusters": master_selector_builder.number_of_feature_clusters,
        "feature_clusters": {k: list(v) for k, v in master_selector_builder.feature_clusters.items()},
        "cluster_mda": cluster_mda_scores,
        "selected_cluster_names": list(master_selector_builder.selected_feature_cluster_names),
        "purged_feature_clusters": {k: list(v) for k, v in master_selector_builder.purged_feature_clusters.items()},
        "feature_sfi": feature_sfi_scores,
        "selected_features": list(master_selector_builder.selected_feature_names)
    }
# Out:
# ManagedMoney_NetPosition_change
# For q=42.0, the optimal variance is 1.0 , and objective function is 2369.33,and max random eigen value: 1.33,and # of signal factors: 6
# ['prior_report_ManagedMoney_NetPosition_change', 'F3_RolledPrice_rolling_20D_volatility', 'F2_RolledPrice_change']
# ManagedMoney_LongPosition_change
# For q=42.0, the optimal variance is 1.0 , and objective function is 2369.33,and max random eigen value: 1.33,and # of signal factors: 6
# ['F3_RolledPrice_rolling_20D_volatility', 'prior_5D_AGG_OI_change', 'prior_cumulative_5D_F1MinusF2_Volume_change', 'F3_RolledPrice_change']
# ManagedMoney_ShortPosition_change
# For q=42.0, the optimal variance is 1.0 , and objective function is 2369.33,and max random eigen value: 1.33,and # of signal factors: 6
# ['prior_5D_F1_OI_change', 'prior_5D_AGG_OI_change', 'prior_cumulative_5D_F1_Volume_change', 'F2_RolledPrice_change']
# ManagedMoney_NetPosition_to_openinterest_change
# For q=42.0, the optimal variance is 1.0 , and objective function is 2369.33,and max random eigen value: 1.33,and # of signal factors: 6
# ['prior_report_ManagedMoney_NetPosition_change', 'prior_5D_AGG_OI_change', 'prior_cumulative_5D_F1MinusF2_Volume_change', 'F2_RolledPrice_change']
# ManagedMoney_LongPosition_to_openinterest_change
# For q=42.0, the optimal variance is 1.0 , and objective function is 2369.33,and max random eigen value: 1.33,and # of signal factors: 6
# ['prior_cumulative_5D_F2_Volume_change', 'prior_5D_F2_OI_change', 'prior_report_ManagedMoney_ShortPosition_to_openinterest_change', 'F1_RolledPrice_change', 'prior_5D_AGG_OI_change', 'prior_cumulative_5D_F1MinusF2_Volume_change']
# ManagedMoney_ShortPosition_to_openinterest_change
# For q=42.0, the optimal variance is 1.0 , and objective function is 2369.33,and max random eigen value: 1.33,and # of signal factors: 6
# ['F2_RolledPrice_rolling_20D_volatility', 'prior_5D_F1_OI_change', 'F2_RolledPrice_change']

# %%
selected_features_by_response
# Out:
# {'ManagedMoney_NetPosition_change': ['prior_report_ManagedMoney_NetPosition_change',
#   'F3_RolledPrice_rolling_20D_volatility',
#   'F2_RolledPrice_change'],
#  'ManagedMoney_LongPosition_change': ['F3_RolledPrice_rolling_20D_volatility',
#   'prior_5D_AGG_OI_change',
#   'prior_cumulative_5D_F1MinusF2_Volume_change',
#   'F3_RolledPrice_change'],
#  'ManagedMoney_ShortPosition_change': ['prior_5D_F1_OI_change',
#   'prior_5D_AGG_OI_change',
#   'prior_cumulative_5D_F1_Volume_change',
#   'F2_RolledPrice_change'],
#  'ManagedMoney_NetPosition_to_openinterest_change': ['prior_report_ManagedMoney_NetPosition_change',
#   'prior_5D_AGG_OI_change',
#   'prior_cumulative_5D_F1MinusF2_Volume_change',
#   'F2_RolledPrice_change'],
#  'ManagedMoney_LongPosition_to_openinterest_change': ['prior_cumulative_5D_F2_Volume_change',
#   'prior_5D_F2_OI_change',
#   'prior_report_ManagedMoney_ShortPosition_to_openinterest_change',
#   'F1_RolledPrice_change',
#   'prior_5D_AGG_OI_change',
#   'prior_cumulative_5D_F1MinusF2_Volume_change'],
#  'ManagedMoney_ShortPosition_to_openinterest_change': ['F2_RolledPrice_rolling_20D_volatility',
#   'prior_5D_F1_OI_change',
#   'F2_RolledPrice_change']}

# %%
import json
with open("wti_cot_mm_nowcast_selected_features_by_response.json", "w") as f:
    json.dump(selected_features_by_response, f)

# %%
## Cache: Feature Selection Details (nowcast)
from src.settings import OUTPUT_DIR

nowcast_output_dir = OUTPUT_DIR / "wti" / "mm" / "nowcast"
nowcast_output_dir.mkdir(parents=True, exist_ok=True)

feature_selection_cache = {
    "ticker": "wti",
    "investor_type": "mm",
    "horizon": "nowcast",
    "all_feature_names": feature_names,
    "responses": feature_selection_details
}

import numpy as np

def numpy_encoder(obj):
    if isinstance(obj, np.integer):
        return int(obj)
    elif isinstance(obj, np.floating):
        return float(obj)
    elif isinstance(obj, np.ndarray):
        return obj.tolist()
    raise TypeError(f"Object of type {type(obj)} is not JSON serializable")

with open(nowcast_output_dir / "02_feature_selection_details.json", "w") as f:
    json.dump(feature_selection_cache, f, indent=2, default=numpy_encoder)
    

# with open(nowcast_output_dir / "02_feature_selection_details.json", "w") as f:
#     json.dump(feature_selection_cache, f, indent=2)

with open(nowcast_output_dir / "02_selected_features_by_response.json", "w") as f:
    json.dump(selected_features_by_response, f, indent=2, default=numpy_encoder)

print(f"Saved 02_feature_selection_details.json and 02_selected_features_by_response.json to {nowcast_output_dir}")
# Out:
# Saved 02_feature_selection_details.json and 02_selected_features_by_response.json to /Users/oualid/Documents/Projects/omroot_repos/COTAME/cache/output/wti/mm/nowcast
